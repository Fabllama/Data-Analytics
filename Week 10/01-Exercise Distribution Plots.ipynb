# %%
#!pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
sample1 = pd.read_csv('Sample_Data_for_Activity.csv')

# %%
print(sample1.head)
# Out:
# <bound method NDFrame.head of      Normal_Distribution  Uniform_Distribution  Exponential_Distribution  \
# 0              57.450712             30.048955                  2.472682
# 1              47.926035             26.274070                  0.374126
# 2              59.715328             58.185815                  1.143180
# 3              72.845448             62.388544                  4.137906
# 4              46.487699             21.895169                 16.224506
# ..                   ...                   ...                       ...
# 995            45.783496             36.840993                 20.984242
# 996            76.965298             32.419555                  4.933213
# 997            59.612643             50.994358                  7.803643
# 998            41.432315             20.330348                 34.440781
# 999            58.588742             20.459842                  0.688837
#
#      Poisson_Distribution
# 0                       4
# ...

# %%
sns.displot(sample1['Uniform_Distribution'], kde=True, color='purple', bins=50)

# %%
sns.displot(sample1['Normal_Distribution'], kde=True, bins=20)

# %%
sns.displot(sample1['Exponential_Distribution'], kde=True, bins=20)

# %%
sns.displot(sample1['Poisson_Distribution'], kde=True, bins=20)
